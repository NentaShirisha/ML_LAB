# %% [markdown]
# Decision Tree
#
# Tiatnic Survival Dataset

# %%
#Import the Necessary Libraries

# %%
import pandas as pd
df=pd.read_csv("train.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x=df.drop(columns='Survived',axis=1)
y=df['Survived']

# %%
x
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
#Load the data sets- train and test

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Printing the dimensions
print("Train Data Shape:", X_train.shape)
print("Test Data Shape:", X_test.shape)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3, random_state=42)
print(df.shape)
# Out:
# (891, 12)

# %%
#Look at top values of train data

# %%
print(df.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#Print the column names of train data

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#Print the dimension of train and test data

# %%
print(x_train.shape,x_test.shape)
# Out:
# (623, 11) (268, 11)

# %%
#Print the number of missing values in each column of train and test data

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#Barchart of Survived, Pclass, Sex, Embarked

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.xlabel("area")
plt.ylabel("price")
plt.title("area vs price")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample dataset (assuming df is already loaded)
# df = pd.read_csv("your_dataset.csv")

# Set plot style
sns.set(style="whitegrid")

# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Plot bar charts
sns.countplot(x="Survived", data=df, ax=axes[0, 0], palette="viridis")
axes[0, 0].set_title("Survival Count")

sns.countplot(x="Pclass", data=df, ax=axes[0, 1], palette="coolwarm")
axes[0, 1].set_title("Passenger Class Count")

sns.countplot(x="Sex", data=df, ax=axes[1, 0], palette="pastel")
axes[1, 0].set_title("Gender Distribution")

sns.countplot(x="Embarked", data=df, ax=axes[1, 1], palette="muted")
axes[1, 1].set_title("Embarked Port Distribution")

# Show plots
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3163/1997884564.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Survived", data=df, ax=axes[0, 0], palette="viridis")
# /tmp/ipykernel_3163/1997884564.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Pclass", data=df, ax=axes[0, 1], palette="coolwarm")
# /tmp/ipykernel_3163/1997884564.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Sex", data=df, ax=axes[1, 0], palette="pastel")
# /tmp/ipykernel_3163/1997884564.py:24: FutureWarning:
#
# ...

# %%
#Histogram of Age, Parch, Fare

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot histograms
sns.histplot(df["Age"], bins=30, kde=True, ax=axes[0], color="blue")
axes[0].set_title("Age Distribution")

sns.histplot(df["Parch"], bins=10, kde=True, ax=axes[1], color="green")
axes[1].set_title("Parch Distribution")

sns.histplot(df["Fare"], bins=30, kde=True, ax=axes[2], color="red")
axes[2].set_title("Fare Distribution")

# Show plots
plt.tight_layout()
plt.show()

# %%
#Plot histogram of age for survived and did not survived class

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Plot histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Age", hue="Survived", bins=30, kde=True, palette={0: "red", 1: "green"}, alpha=0.6)

# Labels and title
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution for Survived and Did Not Survive")

# Show plot
plt.show()

# %%
#Count class and geder wise survival rate - plot with appropriate chart
#Age wise Distribution of Male and Female passengers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set(style="whitegrid")

# Figure setup
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# 1. Count Class and Gender-wise Survival Rate (Grouped Bar Chart)
sns.barplot(x="Pclass", y="Survived", hue="Sex", data=df, ax=axes[0], palette="viridis")
axes[0].set_title("Survival Rate by Class and Gender")
axes[0].set_ylabel("Survival Rate")
axes[0].set_xlabel("Passenger Class")

# 2. Age-wise Distribution of Male and Female Passengers (Histogram)
sns.histplot(data=df, x="Age", hue="Sex", bins=30, kde=True, ax=axes[1], palette={"male": "blue", "female": "pink"}, alpha=0.6)
axes[1].set_title("Age Distribution of Male and Female Passengers")
axes[1].set_xlabel("Age")
axes[1].set_ylabel("Count")

# Show plots
plt.tight_layout()LinearRegression
plt.show()

# %%
#Histogram of Age of the given data set(sample)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.histplot(df["Age"], bins=30, kde=True, color="blue", alpha=0.7)


plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution of Passengers")
plt.show()

# %% [markdown]
# ## Handling Missing Values

# %%
#Replace missing values with 'S' in 'Embarked' column
df = df.assign(Embarked=df["Embarked"].fillna("S"))

# %%
#Impute the missing values in Fare column with median value
df = df.assign(Fare=df["Fare"].fillna(df["Fare"].median()))

# %%
#Impute the Age column. It has too many missing values but it may be important. 
#We fill the missing values with numbers randomly drawn from distribution
#that has same mean and standard deviation as non missing Age data
import numpy as np

# Calculate mean and standard deviation of non-missing Age values
mean_age = df["Age"].mean()
std_age = df["Age"].std()

# Count missing values in Age
missing_count = df["Age"].isnull().sum()

# Generate random values from the same distribution
random_ages = np.random.normal(loc=mean_age, scale=std_age, size=missing_count)

# Fill missing Age values with these random values
df.loc[df["Age"].isnull(), "Age"] = random_ages

# %% [markdown]
# ## Feature Engineering - Creating new features

# %%
# Create and add a new feature FamilySize as a combination of SibSp and Parch
#FamilySize = Parch+SibSp+1
df = df.assign(FamilySize=df["SibSp"]+df["Parch"]+1)

# %%
# Create new feature IsAlone from FamilySize
#If FamilySize == 1 then IsAlone = True else IsAlone = False
df = df.assign(IsAlone=(df["FamilySize"] == 1).astype(int))

# %% [markdown]
# ## Create a new attribute Has_cabin using the attribue Cabin.
# #if Cabin == NaN the Has_cabin = False else Has_cabin = True

# %%
#Drop the columns which may not be useful in prediction of survival
#Drop PassengerId, Name, Ticket, and Cabin
df = df.drop(columns=["PassengerId", "Name", "Ticket", "Cabin"])

# %% [markdown]
# ## Model Building

# %%
#Prepare X and y
X = df.drop(columns=["Survived"]) 
y = df["Survived"]

# %%
# Label encoding of categorical features
from sklearn.preprocessing import LabelEncoder
lab=LabelEncoder()
df['Name']=lab.fit_transform(df['Name'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 4
#       2 from sklearn.preprocessing import LabelEncoder
# ...

# %%
from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()

# Apply Label Encoding only on existing categorical columns
df["Sex"] = lab.fit_transform(df["Sex"])
df["Embarked"] = lab.fit_transform(df["Embarked"])  # If "Embarked" is still present

print(df.head())  # Check the dataset
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0         0       3    1  22.0      1      0   7.2500         2           2
# 1         1       1    0  38.0      1      0  71.2833         0           2
# 2         1       3    0  26.0      0      0   7.9250         2           1
# 3         1       1    0  35.0      1      0  53.1000         2           2
# 4         0       3    1  35.0      0      0   8.0500         2           1
#
#    IsAlone
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1

# %%
# concat df_categorical with original df

# %%
df = pd.concat([df, df_categorical], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df = pd.concat([df, df_categorical], axis=1)
#
# NameError: name 'df_categorical' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the pairplot
sns.pairplot(df, hue="Survived", diag_kind="kde")  

# Show the plot
plt.show()

# %%
X
# Out:
#      Pclass     Sex        Age  SibSp  Parch     Fare Embarked  FamilySize  \
# 0         3    male  22.000000      1      0   7.2500        S           2
# 1         1  female  38.000000      1      0  71.2833        C           2
# 2         3  female  26.000000      0      0   7.9250        S           1
# 3         1  female  35.000000      1      0  53.1000        S           2
# 4         3    male  35.000000      0      0   8.0500        S           1
# ..      ...     ...        ...    ...    ...      ...      ...         ...
# 886       2    male  27.000000      0      0  13.0000        S           1
# 887       1  female  19.000000      0      0  30.0000        S           1
# 888       3  female  24.288434      1      2  23.4500        S           4
# 889       1    male  26.000000      0      0  30.0000        C           1
# 890       3    male  32.000000      0      0   7.7500        Q           1
#
#      IsAlone
# 0          0
# 1          0
# 2          1
# ...

# %%
# Splitting the data into train and validation set - 90% train 10% validation
#X_train, X_test, y_train, y_validation
from sklearn.model_selection import train_test_split

# Splitting the data (90% train, 10% validation)
X_train, X_validation, y_train, y_validation = train_test_split(
    X, y, test_size=0.1, random_state=42, stratify=y
)

# Check the shape of the splits
print("Training set shape:", X_train.shape, y_train.shape)
print("Validation set shape:", X_validation.shape, y_validation.shape)
# Out:
# Training set shape: (801, 9) (801,)
# Validation set shape: (90, 9) (90,)

# %%
# Create the model
# Fitting the decision tree with default hyperparameters
# Importing decision tree classifier from sklearn library
from sklearn.preprocessing import LabelEncoder

# Define categorical columns that need conversion
categorical_columns = ["Sex", "Embarked"]  # Add more if needed

# Apply Label Encoding
encoder = LabelEncoder()
for col in categorical_columns:
    X[col] = encoder.fit_transform(X[col])  # Convert categorical to numerical

# Now, re-split the dataset
X_train, X_validation, y_train, y_validation = train_test_split(
    X, y, test_size=0.1, random_state=42, stratify=y
)

# Train the Decision Tree model again
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_validation)

# Check Accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_validation, y_pred)
print(f"Validation Accuracy: {accuracy:.4f}")
# Out:
# Validation Accuracy: 0.7444

# %%
#Print the tree

# Importing required packages for visualization
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Plot the decision tree
plt.figure(figsize=(15, 8))
plot_tree(model, feature_names=X.columns, class_names=["Not Survived", "Survived"], filled=True, rounded=True)
plt.show()

# %%
# plotting tree with max_depth=3
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Set figure size for better readability
plt.figure(figsize=(15, 8))

# Plot the Decision Tree with max depth of 3
plot_tree(model, feature_names=X.columns, class_names=["Not Survived", "Survived"], 
          filled=True, rounded=True, max_depth=3)

plt.show()

# %% [markdown]
# <img src="tree2.png">

# %%
# Check the evaluation metrics of our default model on validation set - Confusion Matrix, Accuracy, Precision, Recall, F1 score

# Importing classification report and confusion matrix from sklearn metrics

# Making predictions

# Printing classification report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Make predictions
y_pred = model.predict(X_validation)

# Compute confusion matrix
cm = confusion_matrix(y_validation, y_pred)

# Plot confusion matrix using Seaborn
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Not Survived", "Survived"], yticklabels=["Not Survived", "Survived"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Compute accuracy, precision, recall, and F1 score
accuracy = accuracy_score(y_validation, y_pred)
precision = precision_score(y_validation, y_pred)
recall = recall_score(y_validation, y_pred)
f1 = f1_score(y_validation, y_pred)

# Print the classification report
print("\nClassification Report:\n", classification_report(y_validation, y_pred))

# Print individual metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.76      0.79        55
#            1       0.66      0.71      0.68        35
#
#     accuracy                           0.74        90
#    macro avg       0.73      0.74      0.73        90
# weighted avg       0.75      0.74      0.75        90
#
# Accuracy: 0.7444
# Precision: 0.6579
# Recall: 0.7143
# F1 Score: 0.6849

# %%
# Printing confusion matrix and accuracy
from sklearn.metrics import confusion_matrix, accuracy_score

# Make predictions on validation set
y_pred = model.predict(X_validation)

# Compute and print Confusion Matrix
cm = confusion_matrix(y_validation, y_pred)
print("Confusion Matrix:\n", cm)

# Compute and print Accuracy
accuracy = accuracy_score(y_validation, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Confusion Matrix:
#  [[42 13]
#  [10 25]]
# Accuracy: 0.7444
